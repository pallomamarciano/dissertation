# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
keyword = 'kit gay'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
tweets
# Out:
# [{'permalink': 'https://twitter.com/Sergio_lima66/status/1374519361570893834',
#   'pubdate': datetime.datetime(2021, 3, 24, 0, 32, 7, tzinfo=datetime.timezone.utc),
#   'text': 'Quando ele apresentou o Kit Gay na bancada do #JN ninguém o contextou,era conveniente. https://t.co/HMmrU3IvVG',
#   'username': 'Sergio_lima66',
#   'date': datetime.datetime(2021, 3, 24, 0, 32, 7, tzinfo=datetime.timezone.utc)},
#  {'permalink': 'https://twitter.com/LaRvInHaAa1/status/1374518944485179398',
#   'pubdate': datetime.datetime(2021, 3, 24, 0, 30, 28, tzinfo=datetime.timezone.utc),
#   'text': '@kit__gabrielle que gay',
#   'username': 'LaRvInHaAa1',
#   'date': datetime.datetime(2021, 3, 24, 0, 30, 28, tzinfo=datetime.timezone.utc)},
#  {'permalink': 'https://twitter.com/EspecialistaOr1/status/1374516744727842824',
#   'pubdate': datetime.datetime(2021, 3, 24, 0, 21, 43, tzinfo=datetime.timezone.utc),
# ...

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')

# %%
df_tweets.shape
# Out:
# (205795, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-01 03:26:15+0000', tz='UTC')

# %%
df_tweets.to_csv('h_1_20180701_0001.csv')

# %%
keyword = 'kitgay'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (9390, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-02 13:46:39+0000', tz='UTC')

# %%
df_tweets.to_csv('h_2_20180701_0001.csv')

# %%
keyword = 'kit-gay'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (3997, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-01 20:14:30+0000', tz='UTC')

# %%
df_tweets.to_csv('h_3_20180701_0001.csv')

# %%
keyword = 'mamadeira de piroca'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })
# Out:
# Error retrieving https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_composer_source=true&include_ext_alt_text=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=mamadeira+de+piroca+since%3A2018-07-01+lang%3Apt&tweet_search_mode=live&count=100&query_source=spelling_expansion_revert_click&cursor=scroll%3AthGAVUV0VFVBaAgL-B79X47h4WisCsrZ66p5MmEnEVh4AmFYCJehgHREVGQVVMVDUBFeYUFQAA&pc=1&spelling_corrections=1&ext=mediaStats%252CcameraMoment: non-200 status code, retrying

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (168856, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-19 16:09:48+0000', tz='UTC')

# %%
df_tweets.to_csv('h_4_20180701_0001.csv')

# %%
keyword = 'incesto Haddad'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (2324, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-08-31 00:19:55+0000', tz='UTC')

# %%
df_tweets.to_csv('h_5_20180701_0001.csv')

# %%
keyword = 'comunismo Haddad'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (12456, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-03 18:56:40+0000', tz='UTC')

# %%
df_tweets.to_csv('h_6_20180701_0001.csv')

# %%
keyword = 'legalizar pedofilia'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (3003, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-01 21:37:12+0000', tz='UTC')

# %%
df_tweets.to_csv('h_7_20180701_0001.csv')

# %%
keyword = 'confisco de poupança'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (3700, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-09 18:13:40+0000', tz='UTC')

# %%
df_tweets.to_csv('h_8_20180701_0001.csv')

# %%
keyword = 'nós somos mais populares do que Jesus Cristo neste momento'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (3, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-10-05 23:06:51+0000', tz='UTC')

# %%
df_tweets.to_csv('h_9_20180701_0001.csv')

# %%
keyword = 'Movimento nordestinos voltem para casa, o Rio não é lugar para jegue!'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (10, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-10-05 09:53:51+0000', tz='UTC')

# %%
df_tweets.to_csv('h_10_20180701_0001.csv')

# %%
keyword = 'entregou códigos de segurança das urnas eletrônicas para venezuelanos'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (123, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-09-18 01:55:12+0000', tz='UTC')

# %%
df_tweets.to_csv('h_11_20180701_0001.csv')

# %%
keyword = 'Ato em Campinas em prol da saúde do presidente Jair Messias Bolsonaro'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (17, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-09-14 19:45:01+0000', tz='UTC')

# %%
df_tweets.to_csv('h_12_20180701_0001.csv')

# %%
keyword = 'Ato em Campinas'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (850, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-01 22:47:12+0000', tz='UTC')

# %%
df_tweets.to_csv('h_13_20180701_0001.csv')

# %%
keyword = 'Olha Copacabana como está agora!!!'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (50, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-09-29 16:07:23+0000', tz='UTC')

# %%
df_tweets.to_csv('h_14_20180701_0001.csv')

# %%
keyword = 'Jean Wyllys Haddad educação'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (408, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-09-16 04:05:47+0000', tz='UTC')

# %%
df_tweets.to_csv('h_15_20180701_0001.csv')

# %%
keyword = 'Bolsonaro Currículo'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (15056, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-03 13:43:45+0000', tz='UTC')

# %%
df_tweets.to_csv('h_16_20180701_0001.csv')

# %%
keyword = 'Guiné Equatorial BNDES Lula'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (242, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-09-15 23:38:25+0000', tz='UTC')

# %%
df_tweets.to_csv('h_17_20180701_0001.csv')

# %%
keyword = 'Foro de São Paulo'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (190036, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-01 00:09:29+0000', tz='UTC')

# %%
df_tweets.to_csv('h_18_20180701_0001.csv')

# %%
keyword = 'MST Guerra Civil'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (289, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-08 16:07:13+0000', tz='UTC')

# %%
df_tweets.to_csv('h_19_20180701_0001.csv')

# %%
keyword = 'Joaquim Barbosa PT'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (4562, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-05 07:04:42+0000', tz='UTC')

# %%
df_tweets.to_csv('h_20_20180701_0001.csv')

# %%
keyword = 'OEA PT'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (2306, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-04 19:00:01+0000', tz='UTC')

# %%
df_tweets.to_csv('h_21_20180701_0001.csv')

# %%
keyword = 'Urna fraude Haddad'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (536, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-08-06 15:45:14+0000', tz='UTC')

# %%
df_tweets.to_csv('h_22_20180701_0001.csv')

# %%
keyword = 'Urna eletrônica Bolsonaro'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (6895, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-01 11:36:45+0000', tz='UTC')

# %%
df_tweets.to_csv('h_23_20180701_0001.csv')

# %%
keyword = 'Urna eletrônica'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (117702, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-01 00:31:54+0000', tz='UTC')

# %%
df_tweets.to_csv('h_24_20180701_0001.csv')

# %%
keyword = 'facada bolsonaro'
maxTweets = 1000000
tweets = []
tdf = None
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' since:2018-07-01 lang:pt').get_items()) :
        if i > maxTweets :
            break
        username = tweet.username
        text = tweet.content
        date = tweet.date
        pubdate = tweet.date
        permalink = tweet.url
        tweets.append({
            "permalink":permalink,
            "pubdate":pubdate,
            "text":text,
            "username":username,
            "date":date
        })

# %%
df_tweets = pd.DataFrame.from_dict(tweets, orient='columns')
df_tweets.shape
# Out:
# (179977, 5)

# %%
df_tweets['date'].min()
# Out:
# Timestamp('2018-07-13 23:30:19+0000', tz='UTC')

# %%
df_tweets.to_csv('h_25_20180701_0001.csv')
